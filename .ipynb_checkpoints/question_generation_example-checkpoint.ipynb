# %% [markdown]
# importing necessary libraries,
# see installations.txt for the requirements for running this project

# %%
# make sure the following folder is not empty
# !git clone https://github.com/AMontgomerie/question_generator
# Out:
# Cloning into 'question_generator'...

# %%
import sys
print(sys.path)
# Out:
# ['C:\\Users\\Jack\\Final_Project', 'C:\\Users\\Jack\\anaconda3\\envs\\Final_Project\\python38.zip', 'C:\\Users\\Jack\\anaconda3\\envs\\Final_Project\\DLLs', 'C:\\Users\\Jack\\anaconda3\\envs\\Final_Project\\lib', 'C:\\Users\\Jack\\anaconda3\\envs\\Final_Project', '', 'C:\\Users\\Jack\\anaconda3\\envs\\Final_Project\\lib\\site-packages', 'C:\\Users\\Jack\\anaconda3\\envs\\Final_Project\\lib\\site-packages\\win32', 'C:\\Users\\Jack\\anaconda3\\envs\\Final_Project\\lib\\site-packages\\win32\\lib', 'C:\\Users\\Jack\\anaconda3\\envs\\Final_Project\\lib\\site-packages\\Pythonwin']

# %%
import torch
import time

# importing question_generator  - needs to be cloned from github
#sys.path.append("question_generator")

#from questiongenerator import QuestionGenerator
#from questiongenerator import print_qa

#sys.path.append("StoryGame")
#from StoryGame import StoryGame
from StoryGame import StoryGame
print(sys.path)
# Out:
# ['C:\\Users\\Jack\\Final_Project', 'C:\\Users\\Jack\\anaconda3\\envs\\Final_Project\\python38.zip', 'C:\\Users\\Jack\\anaconda3\\envs\\Final_Project\\DLLs', 'C:\\Users\\Jack\\anaconda3\\envs\\Final_Project\\lib', 'C:\\Users\\Jack\\anaconda3\\envs\\Final_Project', '', 'C:\\Users\\Jack\\anaconda3\\envs\\Final_Project\\lib\\site-packages', 'C:\\Users\\Jack\\anaconda3\\envs\\Final_Project\\lib\\site-packages\\win32', 'C:\\Users\\Jack\\anaconda3\\envs\\Final_Project\\lib\\site-packages\\win32\\lib', 'C:\\Users\\Jack\\anaconda3\\envs\\Final_Project\\lib\\site-packages\\Pythonwin']

# %%
sg = StoryGame()
sg.showListOfStories()
sg.chooseStory()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 sg = StoryGame()
# ----> 2 sg.showListOfStories()
#       3 sg.chooseStory()
#
# File ~\Final_Project\StoryGame.py:11, in StoryGame.showListOfStories(self)
#      10 def showListOfStories(self):
# ---> 11     self.list_of_stories = listdir('StoryGame/dataset')
#      12     print("List of stories: ")
#      13     for story in self.list_of_stories:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'StoryGame/dataset'

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
assert device == torch.device('cuda'), "Not using CUDA. Set: Runtime > Change runtime type > Hardware Accelerator: GPU"

# %%
start = time.time()
#qg = QuestionGenerator()
end = time.time()

print('Time for creating QG: ', end - start)

article = open('dataset/1. A jataka tale.txt', encoding="utf-8").read()
# Out:
# time for creating QG:  65.62065362930298

# %%
start = time.time()
qa_list = qg.generate(
    article, 
    num_questions=10, 
    answer_style='all'
)
end = time.time()
print('Time for QG_Generating: ', end - start, '\n')

print_qa(qa_list)
# Out:
# Generating questions...
#
# Evaluating QA pairs...
#
# Time for QG_Generating:  15.713595867156982
#
# 1) Q: What was the king’s expert in selling?
#    A: a horse, but he was an expert in offering astoundingly low value for anything he had to buy.
#
# 2) Q: Who was the only person who could not enjoy the joke?
#    A: Some of them even made jokes about it by estimating how many kingdoms each one of them could buy with rice stored in their houses; in howmany days a good eater could gobble up a kingdom and so on The only persons who could not enjoy the joke the foolish procurator and the as- hamed king who employed him.
#
# 3) Q: What was the fault of the procurator?
#    A: [t is not this poor fellow’s fault that he was made the procurator.
#
# 4) Q: What was the king's intention to buy?
#    A: ” The king hoped that a common fellow without any rank of status would buy nothing without hig: sling and haggling and would be more economical in purchases.
#
# ...
